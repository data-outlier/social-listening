# %% [markdown]
# # Social Listening on Twitter Data

# %% [markdown]
# ## Requirements

# %% [markdown]
# Basic requirements for scrapping on twitter social network:
#
# 1.- Libraries used so far
# 2.- Twitter Developer Profile Credentials
# 3.- Authentication
# 4.- API

# %%
##=============================================================================
## LIBRARIES
##=============================================================================
### This libraires will help us to run all the codes. 
##=============================================================================

import sys, tweepy, json, pandas as pd, seaborn as sns
from datetime import datetime

# %%
##=============================================================================
## CREDENTIALS
##=============================================================================
### These are my personal twitter developer keys to scrap into twitter and get 
### some tweets. 
##=============================================================================

consumer_key = 'q24kCMia4SqAPJDUVMJ21ad1n'
consumer_secret = 'hw4fXnivIuT7ssHX3GfTorFtzlA4xwuTuIqLudTHz1y6yFamUh'
access_token = '1116162409159327745-Y3wDT7tQgJ5rqHWw84ERz3o8yZXM7k'
access_token_secret = 'SfXJEvvrOxonxRgnafCKFT8f5xeDlbUC11YIzOfJpqPvr'

# %%
##=============================================================================
## AUTHENTICATION
##=============================================================================
### This is the way to "log in" into my developer account. 
##=============================================================================
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
##=============================================================================
## API
##=============================================================================
### With this API I can connect my account to twitter and get the twitts. 
##=============================================================================
api = tweepy.API(auth, wait_on_rate_limit = True)

# %% [markdown]
# ## Case One: El Palacio de Hierro

# %% [markdown]
# In this case we will analize what "El Palacio de Hierro" is tweeting (products, services, targets) and what it is being said about this luxury retailer according to people's opinion.

# %% [markdown]
# ### Searching for user basic information

# %% [markdown]
# <img src="images\palace.png">

# %%
#Searching user basic info
data = api.get_user(screen_name ='palaciohierro')
user = json.dumps(data._json, indent = 2)
user_info = json.loads(user)
user_keys = user_info.keys()
print('Nombre:', user_info['name'])
print('Fecha y hora de creación de la cuenta:', user_info['created_at'])
print('User:','@'+user_info['screen_name'])
print('Cuenta verificada:',user_info['verified'])
print('Ubicación:',user_info['location'])
#print(user_info['profile_location'])
print('Descripción:',user_info['description'])
print('Enlaces:',user_info['url'])
print('Seguidores:',user_info['followers_count'])
print('Siguiendo:',user_info['friends_count'])
print('Tweets:',user_info['statuses_count'])
# Out:
# Nombre: El Palacio de Hierro
# Fecha y hora de creación de la cuenta: Thu May 14 14:22:45 +0000 2009
# User: @palaciohierro
# Cuenta verificada: True
# Ubicación: México D.F.
# Descripción: Inspirando y marcando tendencias desde 1888. Taggea tus fotos con #SoyTotalmentePalacio
# Enlaces: https://t.co/oW1NfnMt82
# Seguidores: 824098
# Siguiendo: 198
# Tweets: 79884

# %%
#Searching for tweets of a certain user.
timeline = []
for tweet in tweepy.Cursor(api.user_timeline, screen_name = 'palaciohierro', tweet_mode = 'extended').items(100):
    tweets = json.dumps(tweet._json, indent = 2)
    user_tweets = json.loads(tweets)
    creation = user_tweets.get('created_at')
    text = user_tweets.get('full_text')
    user_reply = user_tweets.get('in_reply_to_screen_name')
    retweets = user_tweets.get('retweet_count')
    favorites = user_tweets.get('favortite_count')
    favorited = user_tweets.get('favorited')
    retweeted = user_tweets.get('retweet')
    language = user_tweets.get('lang')
    tweet_info = [text,creation,user_reply,retweets,favorites,favorited,retweeted,language]
    timeline.append(tweet_info)
timeline
columnas = ['tweets','creation_date','user','retweets','favorites','favorited','retweeted','language']
df = pd.DataFrame(timeline,columns = columnas)

# %%
# Cambiando la fecha del dataframe para dar con hora local (from UTC to CST) 
df['creation_date'] = pd.to_datetime(df['creation_date'])
df['creation_date'].dt.tz
df['creation_date'] = df['creation_date'].dt.tz_convert('America/Mexico_City')

# %%
df.sample(5)
# Out:
#                                                tweets  \
# 69  @cibergirl_ Hola cibergirl_. ¿Cómo te podemos ...
# 41  @marcogallardo77 ¡Hola, Marco! Tu animal prote...
# 46                              @CarlosA89098757 🙌🏻🦅💛
# 43  @Jackie_8Solis ¡Hola, Jacqueline! Tu animal pr...
# 0   @Stylelab11 ¡Hola, Carlos! Tu nahual es el búh...
#
#                creation_date             user  retweets favorites  favorited  \
# 69 2020-09-27 10:45:53-05:00       cibergirl_         0      None      False
# 41 2020-09-27 15:16:34-05:00  marcogallardo77         0      None      False
# 46 2020-09-27 15:11:48-05:00  CarlosA89098757         0      None      False
# 43 2020-09-27 15:14:18-05:00    Jackie_8Solis         0      None      False
# 0  2020-09-27 23:48:37-05:00       Stylelab11         0      None      False
#
#    retweeted language
# 69      None       es
# 41      None       es
# 46      None      und
# 43      None       es
# 0       None       es

# %%
df.to_csv(r'data\c1_cien_tweets_.csv')

# %%
#Searching for specific topics
for tweet in tweepy.Cursor(api.search, q = 'palacio de hierro', tweet_mode = 'extended').items(100):
    print(tweet._json['full_text'], '\n')
# Out:
# RT @JCelectronics: @yeidckol @DiazCanelB Vieja farzante, Ud. piensa con la izquierda y cobra con la derecha. Por cierto ya vió los nuevas p…
#
# @LIRIO_AG @Anaro74 Acabo de ver uno en Tifanny &amp; Co... en Palacio de Hierro por solo 500,000 pesos... y todavía reclaman si llegamos tarde?? Jajaja... es broma... lo del anillo es cierto...
#
# RT @EspirituCurioso: Esta iglesia de estilo francés fue diseñada por Gustave Eiffel, autor del Palacio de hierro en Orizaba y la famosa Tor…
#
# @lopezdoriga @DanielaRomoWeb me sumo a estas condolencias. Conocí a tu madre cuando trabajamos en Palacio de Hierro Centro, yo muy joven, siempre pasaba donde ella por una sonrisa y un chorrito de perfume.Te veía llegar por ella en la noche. Hermosas las dos.
#
# RT @cibergirl_: @palaciohierro RATEROS ,no compren a palacio de hierro
#
# Hoy le lloré a una bolsa Saint Laurent en Palacio de Hierro
#
# RT @Antiamlo100: Saludos @yeidckol !!! Si crees que eso vamos a permitir para #Mexico para que lo entiendas.... estás P E N D E J A. Además…
#
# RT @deniseramosm: No, no es el reloj Rolex, ni los tenis 👟 Gucci, ni las compras en Palacio de Hierro, es la incongruencia, la hipocresía,…
#
# RT @deniseramosm: No, no es el reloj Rolex, ni los tenis 👟 Gucci, ni las compras en Palacio de Hierro, es la incongruencia, la hipocresía,…
#
# Oye @Yeidckol, no te veo yéndote de compras a Cuba, tampoco de vacaciones y mucho menos mandaste a tus bastardos a estudiar ni a trabajar allá.
#
# Te veo muy cómoda comprando en el Palacio de Hierro, seguro a EUA no vas porque ni visa tienes y cruzar el charco te ha de apanicar. https://t.co/QMmSttqWrx
#
# Saludos @yeidckol !!! Si crees que eso vamos a permitir para #Mexico para que lo entiendas.... estás P E N D E J A. Además en Cuba no existe Palacio de Hierro  y aunque la elite comunista consigue muchas cosas, son caras, o para eso son los 300 millones de tu desvio? https://t.co/PZFRq04VV6
#

#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @NoticiasClarasA: #NoEntiendo
#
# Porque la @CondusefMX  no pone un alto al palacio de hierro
#
# No te contestan
#
# #video #Denuncia #Denunc…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @NoticiasClarasA: #NoEntiendo
#
# Porque la @CondusefMX  no pone un alto al palacio de hierro
#
# No te contestan
#
# #video #Denuncia #Denunc…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @NoticiasClarasA: #NoEntiendo
#
# Porque la @CondusefMX  no pone un alto al palacio de hierro
#
# No te contestan
#
# #video #Denuncia #Denunc…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @NoticiasClarasA: #NoEntiendo
#
# Porque la @CondusefMX  no pone un alto al palacio de hierro
#
# No te contestan
#
# #video #Denuncia #Denunc…
#
# @bjperezg1 @AryTovarv No' más le faltó decir no coger y se entiende con la Zopilota en Palacio y no de Hierro, esas están mamitas.
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @NoticiasClarasA: #NoEntiendo
#
# Porque la @CondusefMX  no pone un alto al palacio de hierro
#
# No te contestan
#
# #video #Denuncia #Denunc…
#
# RT @NoticiasClarasA: #NoEntiendo
#
# Porque la @CondusefMX  no pone un alto al palacio de hierro
#
# No te contestan
#
# #video #Denuncia #Denunc…
#
# RT @NoticiasClarasA: #NoEntiendo
#
# Porque la @CondusefMX  no pone un alto al palacio de hierro
#
# No te contestan
#
# #video #Denuncia #Denunc…
#
# #NoEntiendo
#
# Porque la @CondusefMX  no pone un alto al palacio de hierro
#
# No te contestan
#
# #video #Denuncia #DenunciaCiudadana
#
# PESIMO SERVICIO EN ATENCION A CLIENTES DE LA TARJETA PALACIO DE HIERRO /... https://t.co/YlVm7Xbwqn vía @YouTube https://t.co/XXXksDn6gt
#
# @martinezmau @vampipe ya se parece a @yeidckol que bien Castrista y Madurista pero comprando en palacio de hierro y con sus weyes cargandole las bolsitas.
#
# RT @Gustavolester: Si fuera dueño de un circo, claro que lo contrato. Pero si va a pedir trabajo en atención a clientes en palacio de hierr…
#
# Si fuera dueño de un circo, claro que lo contrato. Pero si va a pedir trabajo en atención a clientes en palacio de hierro, pues si está medio cabron. https://t.co/IT4Ntp5ba7
#
# RT @deniseramosm: No, no es el reloj Rolex, ni los tenis 👟 Gucci, ni las compras en Palacio de Hierro, es la incongruencia, la hipocresía,…
#
# RT @MisterChilango: Entras a Palacio de hierro, suspiras y se te van dos mil pesos.
#
# RT @deniseramosm: No, no es el reloj Rolex, ni los tenis 👟 Gucci, ni las compras en Palacio de Hierro, es la incongruencia, la hipocresía,…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# este cuate tiene tan pero tan pero tan estudiado que el otro día que fui a palacio de hierro vi exactamente esto y pues si se llamaba Magaly la otra empleada https://t.co/1PGDgz8Xab
#
# RT @LSK75x: @palaciohierro @jiica Yo llevo 5 meses esperando mi devolución y esta señorita Yadira Arenas A.
# Asesor de Atención a Clientes E…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @deniseramosm: No, no es el reloj Rolex, ni los tenis 👟 Gucci, ni las compras en Palacio de Hierro, es la incongruencia, la hipocresía,…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
#
# RT @fj_grija: Un testimonio de los color cazuela codos percudidos y polvorientos, después de ser acarreados desde sus chiqueros y llegar a…
